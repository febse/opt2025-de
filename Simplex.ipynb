# %% [markdown]
# # Der Simplex Algorithm
#
# | Iteration-1 |       | $C_j$        | 3     | 5         | 0     | 0     | 0     | MinRatio             |
# |-------------|-------|--------------|-------|-----------|-------|-------|-------|----------------------|
# | B           | $C_B$ | $X_B$        | $x_1$ | $x_2$     | $S_1$ | $S_2$ | $S_3$ |                      |
# | $S_1$       | 0     | 8            | 2     | 3         | 1     | 0     | 0     | 2.6667               |
# | $S_2$       | 0     | 2            | 0     | (1)       | 0     | 1     | 0     | 2                   |
# | $S_3$       | 0     | 9            | 3     | 2         | 0     | 0     | 1     | 4.5                 |
# | Z=0         |       | $Z_j$        | 0     | 0         | 0     | 0     | 0     |                      |
# |             |       | $Z_j-C_j$    | -3    | -5 ↑      | 0     | 0     | 0     |                      |

# %% [markdown]
# # Der Simplex Algorithm - Iteration 2
#
# | Iteration-2 |       | $C_j$        | 3     | 5         | 0     | 0     | 0     | MinRatio             |
# |-------------|-------|--------------|-------|-----------|-------|-------|-------|----------------------|
# | B           | $C_B$ | $X_B$        | $x_1$ | $x_2$     | $S_1$ | $S_2$ | $S_3$ |                      |
# | $S_1$       | 0     | 2            | 2     | (2)       | 0     | 1     | 0     | 1                   |
# | $S_3$       | 0     | 5            | 3     | 0         | 0     | 0     | 1     | 1.6667              |
# | $x_2$       | 5     | 2            | 0     | 1         | 0     | 0     | 0     | ---                 |
# | Z=10        |       | $Z_j$        | 0     | 5         | 0     | 5     | 0     |                      |
# |             |       | $Z_j-C_j$    | -3    | 0 ↑       | 0     | 5     | 0     |                      |

# %% [markdown]
# # Der Simplex Algorithm - Iteration 3
#
# | Iteration-3 |       | $C_j$        | 3     | 5         | 0     | 0     | 0     | MinRatio             |
# |-------------|-------|--------------|-------|-----------|-------|-------|-------|----------------------|
# | B           | $C_B$ | $X_B$        | $x_1$ | $x_2$     | $S_1$ | $S_2$ | $S_3$ |                      |
# | $x_1$       | 3     | 1            | 1     | 0         | 0.5   | -1.5  | 0     |                      |
# | $x_2$       | 5     | 2            | 0     | 1         | 0     | 1     | 0     |                      |
# | $S_3$       | 0     | 2            | 0     | 0         | -1.5  | 2.5   | 1     |                      |
# | Z=13        |       | $Z_j$        | 3     | 5         | 1.5   | 0.5   | 0     |                      |
# |             |       | $Z_j-C_j$    | 0     | 0         | 1.5   | 0.5   | 0     |                      |
